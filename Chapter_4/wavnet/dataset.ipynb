# %%
from __future__ import division

import math
import os
import warnings

import numpy as np
import scipy.io.wavfile
import scipy.signal
from picklable_itertools import cycle
from picklable_itertools.extras import partition_all
from tqdm import tqdm
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-d9bd09140154> in <module>
#       8 import scipy.io.wavfile
#       9 import scipy.signal
# ---> 10 from picklable_itertools import cycle
#      11 from picklable_itertools.extras import partition_all
#      12 from tqdm import tqdm
#
# ModuleNotFoundError: No module named 'picklable_itertools'

# %%
# TODO: make SACRED ingredient.
def one_hot(x):
    return np.eye(256, dtype='uint8')[x.astype('uint8')]
