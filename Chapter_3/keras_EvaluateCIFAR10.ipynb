# %%
import numpy as np
import scipy.misc
from keras.models import model_from_json
from keras.optimizers import SGD
# Out:
# Using TensorFlow backend.

# %%
#load model
model_architecture = 'cifar10_architecture.json'
model_weights = 'cifar10_weights.h5'
model = model_from_json(open(model_architecture).read())
model.load_weights(model_weights)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-b845da570b48> in <module>
#       2 model_architecture = 'cifar10_architecture.json'
#       3 model_weights = 'cifar10_weights.h5'
# ----> 4 model = model_from_json(open(model_architecture).read())
#       5 model.load_weights(model_weights)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'cifar10_architecture.json'
